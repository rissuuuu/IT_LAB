# %%
from sklearn.datasets import make_regression 
import matplotlib.pyplot as pl 
import numpy as np 
import pandas as pd 
X,y=make_regression(n_samples=300,n_features=5,noise=10) 
pl.figure(figsize=(10,7)) 
y=y.reshape(-1,1)
print(y.shape)
pl.scatter(x[:,1],y,c=y) 
pl.show()
# Out:
# (300, 1)

# %%
# pl.figure(figsize=(10,7))
# pl.plot()
# pl.scatter(x,y)

# %%
# x.flatten()

# %%
# def Learn(L,reps):
#     m=0
#     c=0
#     n=len(x)
#     # x=x.flatten()
#     for i in range(reps):
#         y_pred=m*x+c
#         d_m=(-2/n)*sum(x*(y-y_pred))
#         d_c=(-2/n)*sum(y-y_pred)
#         m=m-L*d_m
#         c=c-L*d_c
#     print(m,c)
# L=float(input("Enter Learning rate"))
# reps=int(input("Enter number or reps"))
# print(L,reps)
# Learn(L,reps)
# Out:
# Enter Learning rate0.01
# Enter number or reps1000
# 0.01 1000
# 35.9634515895979 0.3523603078557904

# %%
import numpy as np
M = np.random.rand(5,1)
c=0
n=X.shape[0]

L=0.01
reps=1000

listoferror=[]

for i in range(reps):
    y_pred=np.matmul(X,M)+c
    d_m=(-2/n)*np.sum(X*(y-y_pred), axis=0)
    d_c=(-2/n)*np.sum(y-y_pred)
    #print(d_m, d_c)
    m=m-L*d_m
    c=c-L*d_c
    
    errors=np.square(np.subtract(y,y_pred))
    err=np.mean(errors)
    listoferror.append(err)
print(m,c)
#print(listoferror)
# Out:
# [ 9295.06053768 11492.13240022  8767.6560223   9896.12851081
#  10822.55421707] 5.974206761453188

# %%
pl.plot(listoferror)

# %%
pl.figure(figsize=(10,7))
y_pred=m*x+c
pl.scatter(x,y,c=y)
pl.plot(x,y_pred,c="r")
pl.show()
len(listoferror)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-170-bf8d32521ba2> in <module>
#       1 pl.figure(figsize=(10,7))
#       2 y_pred=m*x+c
# ----> 3 pl.scatter(x,y,c=y)
#       4 pl.plot(x,y_pred,c="r")
#       5 pl.show()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4442         y = np.ma.ravel(y)
#    4443         if x.size != y.size:
# -> 4444             raise ValueError("x and y must be the same size")
#    4445
#    4446         if s is None:
#
# ValueError: x and y must be the same size

# %%
pl.figure(figsize=(10,8))
pl.plot(listoferror)
pl.show()
